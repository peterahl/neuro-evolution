# %%
import csv
import matplotlib.pyplot as plt

# %matplotlib inline

# cd src
# ./run_experiment simple_ann_evolution | tee ../tmp/simple_ann_evolution.csv

# %%
with open("../tmp/simple_ann_evolution.csv", "r") as f:
    csv_reader = csv.reader(f, delimiter=" ")
    data = list(zip(*[(i - 8, int(x[-1]), int(x[0])) for i, x in enumerate(csv_reader) if i > 7]))
plt.figure(figsize=(16, 9))
plt.plot(data[0], data[1])
plt.plot(data[0], data[2])
plt.savefig("../tmp/simple_ann_evolution.png")
